# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sklearn

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import (
    KFold,
    StratifiedKFold,
    LeaveOneOut,
    TimeSeriesSplit,
    cross_val_score
)
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

model = RandomForestClassifier(random_state=42)

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(model, X, y, cv=kfold)

print("K-Fold Scores:", scores)
print("Average Accuracy:", scores.mean())
# Out:
# K-Fold Scores: [0.95614035 0.96491228 0.93859649 0.96491228 0.96460177]
# Average Accuracy: 0.9578326346840551

# %%
skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

scores = cross_val_score(model, X, y, cv=skf)

print("Stratified K-Fold Scores:", scores)
print("Average Accuracy:", scores.mean())
# Out:
# Stratified K-Fold Scores: [0.96491228 0.93859649 0.95614035 0.94736842 0.97345133]
# Average Accuracy: 0.9560937742586555

# %%
loo = LeaveOneOut()

scores = cross_val_score(
    model,
    X,
    y,
    cv=loo
)

print("Number of Folds:", len(scores))
print("Average Accuracy:", scores.mean())
# Out:
# Number of Folds: 569
# Average Accuracy: 0.961335676625659

# %%
from sklearn.model_selection import TimeSeriesSplit
import numpy as np

X = np.arange(20).reshape(-1, 1)
y = np.arange(20)

tscv = TimeSeriesSplit(n_splits=5)

for train_idx, test_idx in tscv.split(X):
    print("Train:", train_idx)
    print("Test :", test_idx)
    print("-" * 40)
